# %%
# %%writefile conf/config.yaml
# defaults :
#   - modulus_default
#   - arch:
#       - fully_connected
#   - scheduler: tf_exponential_lr
#   - optimizer: adam
#   - loss: sum
#   - _self_
#
# save_filetypes : "vtk,npz"
#
# scheduler:
#   decay_rate: 0.95
#   decay_steps: 100
#
# training:
#   rec_results_freq: 1000
#   max_steps: 10000
#
# batch_size:
#   IC: 3000
#   interior:  3000
# Out:
# Overwriting conf/config.yaml

# %%
# %%writefile fhnModulus.py
from modulus.models.fully_connected import FullyConnectedArch

from sympy import Symbol, Eq
from sympy import Symbol, Function, Number
from modulus.eq.pde import PDE
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate
import modulus
from modulus.hydra import instantiate_arch, ModulusConfig
from modulus.solver import Solver
from modulus.domain import Domain
from modulus.geometry.primitives_1d import Point1D
from modulus.domain.constraint import (
    PointwiseBoundaryConstraint,
    PointwiseBoundaryConstraint,
)
from modulus.domain.validator import PointwiseValidator
from modulus.key import Key
from modulus.node import Node
from modulus.eq.pde import PDE
from modulus.geometry import Parameterization
a=0.001
def generateExactSolution(t,dt,x0,P):
    
    n=int(t/dt)
    Sol=np.zeros(n)
    Sol[0]=x0
    T=0
    k=0
    while(k<n-1):
        x=Sol[k]
        Sol[k+1]=P*x*(x)*(1-x)*dt +  x
        T=T+dt
        k=k+1
    return Sol

class SpringMass(PDE):
    name = "FHN"

    def __init__(self):

      
     

        t,k = Symbol("t"),Symbol("K")
        input_variables = {"t": t,"K":k}

        x1 = Function("x1")(*input_variables)



        self.equations = {}
        self.equations["ode_x1"] = k*x1*(1-x1)*(x1) -x1.diff(t)

                                    
                                    
        
@modulus.main(config_path="conf", config_name="config")
def run(cfg: ModulusConfig) -> None:
    u0=0.7
    # make list of nodes to unroll graph on
    sm = SpringMass()
    sm.pprint()
    sm_net = FullyConnectedArch(
        input_keys=[Key("t"), Key("K")],
        output_keys=[Key("x1")],
    )
    nodes = sm.make_nodes() + [
        sm_net.make_node(name="network")
    ]

   
    # add constraints to solver
    # make geometry
    geo = Point1D(0)
    t_max = 10.0
    t_symbol = Symbol("t")
    u_symbol = Symbol("x1")
    k_symbol= Symbol("K")
    time_range = {t_symbol: (0, t_max)}

    # make domain
    domain = Domain()

    # initial conditions
    IC = PointwiseBoundaryConstraint(
        nodes=nodes,
        geometry=geo,
        outvar={"x1": u0},
        batch_size=cfg.batch_size.IC,
        lambda_weighting={
            "x1": 1.0,


        },
        parameterization={t_symbol: 0,**{k_symbol: (0.1, 1)}},
    )
    domain.add_constraint(IC, name="IC")

    
    
    # solve over given time period
    interior = PointwiseBoundaryConstraint(
        nodes=nodes,
        geometry=geo,
        outvar={"ode_x1": 0.0},
        batch_size=cfg.batch_size.interior,
        parameterization={**time_range,**{k_symbol: (0.1, 1)}},
    )
    domain.add_constraint(interior, "interior")
    
    # add validation data
  
 
    T=np.empty([0])
    K=np.empty([0])
    SOLs=np.empty([0])
    krange=[0.1*i for i in range(1,10)]
    
    deltaT = 0.01
    
    
    for KR in krange:
        t = np.arange(0, t_max, deltaT)
        t = np.expand_dims(t, axis=-1)
        T=np.append(T,t)
        K = np.append(K,np.full_like (t,KR))
        SOLs=np.append(SOLs,np.array(generateExactSolution(t_max,deltaT,u0,KR)))

    
    
    
    
    
    
    
    
    t=np.expand_dims(T,axis=-1)
    k=np.expand_dims(K,axis=-1)
    sol=SOLs
    
    invar_numpy = {"t": t,"K":k}
    outvar_numpy = {
        "x1": sol
    }
    validator = PointwiseValidator(
        nodes=nodes, invar=invar_numpy, true_outvar=outvar_numpy, batch_size=1024
    )
    domain.add_validator(validator)

    # make solver
    slv = Solver(cfg, domain)

    # start solver
    slv.solve()


if __name__ == "__main__":
    run()
# Out:
# Overwriting fhnModulus.py

# %%
# !rm -r outputs || true ##se não limpar o output ele aproveita o treinamento, mesmo se mudar o modelo
# !python fhnModulus.py
# Out:
# [01:07:24] - JIT using the NVFuser TorchScript backend
# [01:07:24] - JitManager: {'_enabled': True, '_arch_mode': <JitArchMode.ONLY_ACTIVATION: 1>, '_use_nvfuser': True, '_autograd_nodes': False}
# [01:07:24] - GraphManager: {'_func_arch': False, '_debug': False, '_func_arch_allow_partial_hessian': True}
# ode_x1: K*(1 - x1)*x1**2 - x1__t
# [01:07:27] - Installed PyTorch version 1.13.1+cu117 is not TorchScript supported in Modulus. Version 1.13.0a0+d321be6 is officially supported.
# [01:07:27] - attempting to restore from: outputs/fhnModulus
# [01:07:27] - optimizer checkpoint not found
# [01:07:27] - model network.0.pth not found
# [01:07:29] - [step:          0] record constraint batch time:  4.874e-01s
# [01:07:30] - [step:          0] record validators time:  7.460e-01s
# [01:07:30] - [step:          0] saved checkpoint to outputs/fhnModulus
# [01:07:30] - [step:          0] loss:  4.833e-01
# [01:07:33] - Attempting cuda graph building, this may take a bit...
# [01:07:38] - [step:        100] loss:  1.909e-01, time/iteration:  8.312e+01 ms
# [01:07:45] - [step:        200] loss:  9.697e-02, time/iteration:  6.906e+01 ms
# [01:07:52] - [step:        300] loss:  7.194e-02, time/iteration:  6.959e+01 ms
# [01:07:59] - [step:        400] loss:  5.061e-02, time/iteration:  6.644e+01 ms
# [01:08:05] - [step:        500] loss:  3.166e-02, time/iteration:  6.749e+01 ms
# [01:08:12] - [step:        600] loss:  2.026e-02, time/iteration:  6.790e+01 ms
# [01:08:19] - [step:        700] loss:  1.580e-02, time/iteration:  6.743e+01 ms
# [01:08:26] - [step:        800] loss:  1.174e-02, time/iteration:  6.846e+01 ms
# [01:08:33] - [step:        900] loss:  1.010e-02, time/iteration:  6.765e+01 ms
# [01:08:39] - [step:       1000] record constraint batch time:  5.964e-02s
# [01:08:39] - [step:       1000] record validators time:  4.712e-01s
# [01:08:39] - [step:       1000] saved checkpoint to outputs/fhnModulus
# [01:08:39] - [step:       1000] loss:  9.002e-03, time/iteration:  6.864e+01 ms
# [01:08:42] - [step:       1100] loss:  7.330e-03, time/iteration:  3.000e+01 ms
# [01:08:45] - [step:       1200] loss:  5.764e-03, time/iteration:  2.957e+01 ms
# [01:08:48] - [step:       1300] loss:  5.091e-03, time/iteration:  2.968e+01 ms
# [01:08:51] - [step:       1400] loss:  4.326e-03, time/iteration:  2.977e+01 ms
# [01:08:54] - [step:       1500] loss:  3.784e-03, time/iteration:  2.967e+01 ms
# [01:08:57] - [step:       1600] loss:  3.051e-03, time/iteration:  2.970e+01 ms
# [01:09:00] - [step:       1700] loss:  2.758e-03, time/iteration:  2.978e+01 ms
# [01:09:03] - [step:       1800] loss:  2.181e-03, time/iteration:  2.975e+01 ms
# [01:09:06] - [step:       1900] loss:  1.826e-03, time/iteration:  2.981e+01 ms
# [01:12:14] - [step:       7900] loss:  9.849e-05, time/iteration:  2.978e+01 ms
# [01:12:17] - [step:       8000] record constraint batch time:  2.491e-02s
# [01:12:18] - [step:       8000] record validators time:  4.551e-01s
# [01:12:18] - [step:       8000] saved checkpoint to outputs/fhnModulus
# [01:12:18] - [step:       8000] loss:  8.685e-05, time/iteration:  4.407e+01 ms
# [01:12:21] - [step:       8100] loss:  8.872e-05, time/iteration:  3.001e+01 ms
# [01:12:24] - [step:       8200] loss:  8.676e-05, time/iteration:  2.970e+01 ms
# [01:12:27] - [step:       8300] loss:  8.779e-05, time/iteration:  2.974e+01 ms
# [01:12:30] - [step:       8400] loss:  8.434e-05, time/iteration:  2.980e+01 ms
# [01:12:33] - [step:       8500] loss:  8.028e-05, time/iteration:  2.975e+01 ms
# [01:12:36] - [step:       8600] loss:  8.058e-05, time/iteration:  2.969e+01 ms
# [01:12:39] - [step:       8700] loss:  8.083e-05, time/iteration:  2.970e+01 ms
# [01:12:42] - [step:       8800] loss:  6.776e-05, time/iteration:  2.973e+01 ms
# [01:12:45] - [step:       8900] loss:  7.651e-05, time/iteration:  2.976e+01 ms
# [01:12:49] - [step:       9000] record constraint batch time:  2.717e-02s
# [01:12:49] - [step:       9000] record validators time:  4.716e-01s
# [01:12:49] - [step:       9000] saved checkpoint to outputs/fhnModulus
# [01:12:49] - [step:       9000] loss:  7.586e-05, time/iteration:  4.429e+01 ms
# [01:12:52] - [step:       9100] loss:  7.150e-05, time/iteration:  3.007e+01 ms
# [01:12:55] - [step:       9200] loss:  7.314e-05, time/iteration:  2.967e+01 ms
# [01:12:58] - [step:       9300] loss:  7.078e-05, time/iteration:  2.972e+01 ms
# [01:13:01] - [step:       9400] loss:  7.979e-05, time/iteration:  2.970e+01 ms
# [01:13:04] - [step:       9500] loss:  6.795e-05, time/iteration:  2.973e+01 ms
# [01:13:07] - [step:       9600] loss:  7.540e-05, time/iteration:  2.974e+01 ms
# [01:13:10] - [step:       9700] loss:  6.981e-05, time/iteration:  2.982e+01 ms
# [01:13:13] - [step:       9800] loss:  7.067e-05, time/iteration:  2.987e+01 ms
# [01:13:16] - [step:       9900] loss:  7.388e-05, time/iteration:  2.974e+01 ms
# [01:13:20] - [step:      10000] record constraint batch time:  2.494e-02s
# [01:13:20] - [step:      10000] record validators time:  4.592e-01s
# [01:13:20] - [step:      10000] saved checkpoint to outputs/fhnModulus
# [01:13:20] - [step:      10000] loss:  6.207e-05, time/iteration:  4.411e+01 ms
# [01:13:20] - [step:      10000] reached maximum training steps, finished training!

# %%
import numpy as np
import matplotlib.pyplot as plt

def find(list_to_check, item_to_find):
    return [idx for idx, value in enumerate(list_to_check) if value == item_to_find]

base_dir = "outputs/fhnModulus/validators/"

# plot in 1d
data = np.load(base_dir + "validator.npz", allow_pickle=True)
data = np.atleast_1d(data.f.arr_0)[0]

ks=np.unique(data["K"])
t=np.unique(data["t"])
for k in ks:
    i=find(data["K"],k)
    #print(i)
    x=data["true_x1"][i]
    pred=data["pred_x1"][i]
    
    plt.plot(t,x,label="True ,k ="+ str(k))
    plt.plot(t,pred,label="Pred ,k ="+ str(k))
    plt.legend(loc="best")
    plt.show()
